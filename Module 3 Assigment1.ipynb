# %%
#Program to find GDF 
a=int(input("Enter the First number="))
b=int(input("Enter the Second number="))
while a!=b:
    if a>b:
        a=a-b
    else:
        b=b-a
print("GCD=",a)
# Out:
# Enter the First number=6
# Enter the Second number=3
# GCD= 3

# %%
#Accept a word and reverse it
word = input("Input a word to reverse: ")

for char in range(len(word) - 1, -1, -1):
  print(word[char], end="")
print("\n")
# Out:
# Input a word to reverse: india
# aidni

# %%
#count the even and odd number of the series
n=int(input("Enter the number till where you have to count the series:"))
e,o=0,0
for i in range(0,n):
    if i%2==0:
        e=e+1
    else:
        o=o+1
print("Total number of even numbers=",e," Total number of odd numbers=",o)
# Out:
# Enter the number till where you have to count the series:5
# Total number of even numbers= 3  Total number of odd numbers= 2

# %%
#Program to print 0-6 exceot 3 and 6
for i in range(0,6):
    if i%3!=0:
        print(" ",i)
# Out:
#   1
#   2
#   4
#   5
